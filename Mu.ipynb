# %% [markdown]
# # #1  Population
# I chose to use the population of each neighborhood as one of my metrics. My reasoning is that when people choose to live in a particular neighborhood, there are usually strong pull factors, such as good resources, services, and accessibility, that attract them there. In addition, when a neighborhood has a larger population, residents often contribute to the area by opening shops, businesses, and community services that further enrich local resources. Overall, population serves as a meaningful indicator of how many resource a neighborhood is has.

# %% [markdown]
# The dataset has multiple columns with specific population of different races of the year 2010 and 2020. With the rows being the neighborhood.

# %%
import pandas as pd
data = pd.read_csv("Population.csv")
data.head(10)
# Out:
#                                Neighborhood  2010_Total_Population  \
# 0                          Allegheny Center                    933
# 1                            Allegheny West                    462
# 2                                 Allentown                   2500
# 3  Arlington - Arlington Heights (Combined)                   2113
# 4                                Banksville                   4144
# 5                         Bedford Dwellings                   1202
# 6                                 Beechview                   7974
# 7                               Beltzhoover                   1925
# 8                                Bloomfield                   8442
# 9                                     Bluff                   6600
#
#    2010_OneRace_Population  2010_White_Alone_Population  \
# 0                      896                          381
# 1                      448                          354
# 2                     2384                         1485
# ...

# %% [markdown]
# # Analysis
# After analyzing the data, I decided to make a deeper analysis. I decide to use the change in total population from 2010 to 2020 as another deciding factor. I first need the top 10 largest population number and will rank that. On top of that I will another graph that shows the top 10 neighbrohood with the the highestpositive population change from 2010 to 2020. The logic of someone moving out of a neighborhood would indicate that the person found a better neighborhood to live in so the neighborhood with the most amount of positive change will also be taken into consideration.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Population.csv")

# ---------------------------
# graph 1: top 10 by 2020 total population
# ---------------------------
g1 = df.sort_values("2020_Total_Population", ascending=False).head(10)

plt.figure()
bars = plt.bar(g1["Neighborhood"], g1["2020_Total_Population"])
plt.xticks(rotation=45, ha="right")
plt.ylabel("2020 total population")
plt.title("Top 10 Neighborhoods by 2020 Population")

# add numbers on top
ax = plt.gca()
plt.ylim(0, g1["2020_Total_Population"].max() * 1.10)
for b in bars:
    y = b.get_height()
    ax.text(b.get_x() + b.get_width()/2, y, str(int(y)), ha="center", va="bottom", fontsize=8)

plt.tight_layout()
plt.show()

# ---------------------------
# graph 2: top 10 highest *positive* change 2010→2020
# ---------------------------
pos = df[df["Change_2010_to_2020_Total_Population"] > 0]
g2 = pos.sort_values("Change_2010_to_2020_Total_Population", ascending=False).head(10)

plt.figure()
bars = plt.bar(g2["Neighborhood"], g2["Change_2010_to_2020_Total_Population"])
plt.xticks(rotation=45, ha="right")
plt.ylabel("Change in population (2010–2020)")
plt.title("Top 10 Neighborhoods by Population Increase (2010–2020)")

ax = plt.gca()
plt.ylim(0, g2["Change_2010_to_2020_Total_Population"].max() * 1.10)
for b in bars:
    y = b.get_height()
    ax.text(b.get_x() + b.get_width()/2, y, str(int(y)), ha="center", va="bottom", fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## After Code Analysis
# When looking at the grpah.  write something like I looked at the graph I first looked at the top 3 largest population grpah. After I looked for thoose three neightborhoods in the second grpah, which shows the top 10 population with positive increase. After I would look at the final grpah to see if any of the three neighborhoods. In this case Shadyside is a clear winner becuase even though it is tied for first place, Shadyside has a high postive population increase, which means that there are great pull factors that are pulling people to move into the nieghborhood, like great resources.

# %% [markdown]
# ## Conclusion
# The best neighborhood in Pittsburgh based on this metric is Shadyside. Followed by Squirrel Hill South Brookline and Squirrel Hill North.

# %% [markdown]
# # Pros and Cons Using This Metric
#
# ## **Pros**
# - It shows how popular or attractive a neighborhood is, if a neighborhood's population grows that means more people wnats to live there.
# - Growing Neighborhood often see more city investments, like new roads, public transits and park. Which means that this neighborhood has more resources.
#
#
# ## **Cons**
# - The data doesn't specify who is moving in or out, like high income, low income, students, etc. Becuases the type of change matters
